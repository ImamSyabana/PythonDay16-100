# %%
from bs4 import BeautifulSoup
import requests
from datetime import datetime
import string
import smtplib

import os
from dotenv import find_dotenv, load_dotenv

# %%
URL = "https://appbrewery.github.io/instant_pot/"

headers = {
    #Accept: "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7",
    #Accept-Encoding: "gzip, deflate, br, zstd",
    "Accept-Language": "en-GB,en;q=0.9,ja-JP;q=0.8,ja;q=0.7,en-US;q=0.6",
    #Host: "httpbin.org",
    #Priority: "u=0, i",
    #Sec-Ch-Ua: ""Not)A;Brand";v="8", "Chromium";v="138", "Google Chrome";v="138"",
    #Sec-Ch-Ua-Mobile: "?0",
    #Sec-Ch-Ua-Platform: ""Windows"",
    #Sec-Fetch-Dest: "document",
    #Sec-Fetch-Mode: "navigate",
    #Sec-Fetch-Site: "cross-site",
    #Sec-Fetch-User: "?1",
    #Upgrade-Insecure-Requests: "1",
    #"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36",
    #X-Amzn-Trace-Id: "Root=1-6874ff89-65e6cc15727076c9189f8ec6"
    "user-agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36"
}
response = requests.get(URL, headers=headers)

# %%
raw_web_page = response.text #mengeluarkan html beserta semua tag2 nya
raw_web_page
# Out:
# '<!doctype html>\r\n<html lang="en-us" class="a-no-js" data-19ax5a9jf="dingo">\r\n\r\n<head>\r\n    <script>var aPageStart = (new Date()).getTime();</script>\r\n    <meta charset="utf-8" />\r\n    <script type=\'text/javascript\'>var ue_t0 = ue_t0 || +new Date();</script>\r\n    <meta http-equiv=\'x-dns-prefetch-control\' content=\'on\'>\r\n    <link rel="icon" type="image/png"\r\n        href="https://d2vvqscadf4c1f.cloudfront.net/vz7d3KSRSQ6tfzXoQJfE_LABlogoCircularSmall.png">\r\n\r\n\r\n    <link rel="stylesheet" href="styles/styles.css">\r\n    <script>\r\n        (function (b, a, c, d) { if ((b = b.AmazonUIPageJS || b.P) && b.when && b.register) { c = []; for (a = a.currentScript; a; a = a.parentElement)a.id && c.push(a.id); return b.log("A copy of P has already been loaded on this page.", "FATAL", c.join(" ")) } })(window, document, Date); (function (a, b, c, d) { "use strict"; a._pSetI = function () { return null } })(window, document, Date); (function (d, I, K, L) {\r\n            "use strict"; d._sw = function () {\r\n                var p; return function (w, g, u, B, h, C, q, k, x, y) {\r\n                    p || (p = !0, y.execute("RetailPageServiceWorker", function () {\r\n                        function z(a, b) { e.controller && a ? (a = { feature: "retail_service_worker_messaging", command: a }, b && (a.data = b), e.controller.postMessage(a)) : a && h("sw:sw_message_no_ctrl", 1) } function p(a) {\r\n                            var b = a.data; if (b && "retail_service_worker_messaging" === b.feature && b.command && b.data) {\r\n                                var c = b.data; a = d.ue; var f = d.ueLogError; switch (b.command) {\r\n                                    case "log_counter": a && k(a.count) &&\r\n                                        c.name && a.count(c.name, 0 === c.value ? 0 : c.value || 1); break; case "log_tag": a && k(a.tag) && c.tag && (a.tag(c.tag), b = d.uex, a.isl && k(b) && b("at")); break; case "log_error": f && k(f) && c.message && f({ message: c.message, logLevel: c.level || "ERROR", attribution: c.attribution }); break; case "log_weblab_trigger": if (!c.weblab || !c.treatment) break; a && k(a.trigger) ? a.trigger(c.weblab, c.treatment) : (h("sw:wt:miss"), h("sw:wt:miss:" + c.weblab + ":" + c.treatment)); break; default: h("sw:unsupported_message_command", 1)\r\n                                }\r\n                            }\r\n                        }\r\n                        function v(a, b) { return "sw:" + (b || "") + ":" + a + ":" } function D(a, b) { e.register("/service-worker.js").then(function () { h(a + "success") }).catch(function (c) { y.logError(c, "[AUI SW] Failed to " + b + " service worker: ", "ERROR"); h(a + "failure") }) } function E() { l.forEach(function (a) { q(a) }) } function n(a) { return a.capabilities.isAmazonApp && a.capabilities.android } function F(a, b, c) {\r\n                            if (b) if (b.mshop && n(a)) a = v(c, "mshop_and"), b = b.mshop.action, l.push(a + "supported"), b(a, c); else if (b.browser) {\r\n                                a = u(/Chrome/i) &&\r\n                                    !u(/Edge/i) && !u(/OPR/i) && !a.capabilities.isAmazonApp && !u(new RegExp(B + "bwv" + B + "b")); var f = b.browser; b = v(c, "browser"); a ? (a = f.action, l.push(b + "supported"), a(b, c)) : l.push(b + "unsupported")\r\n                            }\r\n                        } function G(a, b, c) { a && l.push(v("register", c) + "unsupported"); b && l.push(v("unregister", c) + "unsupported"); E() } try { var e = "" } catch (a) { q("sw:nav_err") } (function () {\r\n                            if (e) {\r\n                                var a = function () { z("page_loaded", { rid: d.ue_id, mid: d.ue_mid, pty: d.ue_pty, sid: d.ue_sid, spty: d.ue_spty, furl: d.ue_furl }) }; x(e, "message",\r\n                                    p); z("client_messaging_ready"); y.when("load").execute(a); x(e, "controllerchange", function () { z("client_messaging_ready" ...

# %%
soup = BeautifulSoup(raw_web_page, "html.parser") #membuat object untuk parsing html

# %%
product_title = soup.find(name = "span", id = "productTitle")
product_title =product_title.get_text()
product_title = product_title.split("\r\n                                        ")
product_title = " ".join(product_title)
product_title = product_title.strip()
product_title
# Out:
# 'Instant Pot Duo Plus 9-in-1 Electric Pressure Cooker, Slow Cooker, Rice Cooker, Steamer, Sauté, Yogurt Maker, Warmer & Sterilizer, Includes App With Over 800 Recipes, Stainless Steel, 3 Quart'

# %%
price_tag = soup.find(name = "span", class_ = "aok-offscreen")
price_tag = price_tag.get_text()
price_tag = price_tag.strip()
price_tag = price_tag[1:]
price_tag = float(price_tag)
price_tag
# Out:
# 99.99

# %% [markdown]
# # Mengirim email dan menyimpan credentials di env variabel

# %%
# mencari lokasi file .env secara otomatis 
dotenv_path = find_dotenv()

# load the entries as environtment variables
load_dotenv(dotenv_path)
# Out:
# True

# %%
# stored the env variables within a python variable
my_email = os.getenv("my_email")
my_password = os.getenv("my_password")
email_penerima = os.getenv("email_imam")

# %%
my_password
# Out:
# 'otlcxftlknqbeype'

# %%
treshold = 100.00

if price_tag < treshold:
    # send an email

    with smtplib.SMTP("smtp.gmail.com", 587) as connection:
        connection.starttls() #TLS : transport layer security
        connection.login(user = my_email, password = my_password)
        connection.sendmail(from_addr = my_email, 
                            to_addrs= email_penerima,
                            msg=f"Subject:Amazon Price Alert!\n\n{product_title} is now ${price_tag}".encode("utf-8"))

else:
    print(f"Harga belum turun di bawah {treshold}")
